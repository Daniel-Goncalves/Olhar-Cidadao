# %%
import base64
import logging
import tornado.web
from tornado import gen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests
import re
import os
import xlrd
import copy

# %%
def create_column(df,nm):
	df['{}'.format(nm)]=[]

# %%
def read_excel(file):
	return pd.ExcelFile(file).parse(pd.ExcelFile(file).sheet_names[0])

# %%
path="handlers/Excel"

# %%
df_materiais = pd.DataFrame({})
df_licitacoes = pd.DataFrame({})
df_lotes = pd.DataFrame({})
tabela_unica = pd.DataFrame({})

# %%
create_column(df_licitacoes,'Licitações')
create_column(df_licitacoes,'Lotes')

create_column(df_lotes,'Licitações')
create_column(df_lotes,'Lotes')

# %%
arr_licitacoes=os.listdir(path)

# %%
arr_lotes=[]
arr_infos=[]
for diretorio in arr_licitacoes:
    arr_lotes+=[os.listdir('{}/{}'.format(path, diretorio))]
    arr_infos+=[os.listdir('{}/{}/{}'.format(path, diretorio,'Lotes'))]
arr_lotes2 = copy.deepcopy(arr_lotes)

# %%
arr_lotes
# Out:
# [['Lotes', 'infos.xlsx'],
#  ['Lotes', 'infos.xlsx'],
#  ['Lotes', 'infos.xlsx'],
#  ['Lotes', 'infos.xlsx'],
#  ['Lotes', 'infos.xlsx']]

# %%
for i in range(len(arr_lotes2)):
    for j in range(len(arr_lotes2[i])):
        if arr_lotes2[i][j] == 'Lotes':
            arr_lotes[i].remove(arr_lotes[i][j])
        else:
            continue 
arr_lotes3 = copy.deepcopy(arr_lotes)

# %%
arr_lotes
# Out:
# [['infos.xlsx'],
#  ['infos.xlsx'],
#  ['infos.xlsx'],
#  ['infos.xlsx'],
#  ['infos.xlsx']]

# %%
for k in range(len(arr_lotes3)):
    for l in range(len(arr_lotes3[k])):
        if arr_lotes3[k][l][0] == '.':
            arr_lotes[k].remove(arr_lotes[k][l])
            break
        else:
            continue 
arr_lotes4 = copy.deepcopy(arr_lotes)

# %%
arr_infos
# Out:
# [['Lote9.xlsx',
#   'Lote6.xlsx',
#   'Lote5.xlsx',
#   'Lote8.xlsx',
#   'Lote3.xlsx',
#   'Lote1.xlsx',
#   'Lote7.xlsx',
#   'Lote2.xlsx'],
#  ['lote12.xlsx',
#   'lote2.xlsx',
#   'lote3.xlsx',
#   'lote5.xlsx',
#   'lote1.xlsx',
#   'lote17.xlsx',
#   'lote16.xlsx',
#   'lote8.xlsx',
#   'lote15.xlsx',
#   'lote11.xlsx',
#   'lote4.xlsx',
#   'lote10.xlsx',
#   'lote14.xlsx',
#   'lote7.xlsx',
#   'lote18.xlsx',
#   'lote9.xlsx',
#   'lote6.xlsx'],
#  ['lote12.xlsx',
#   'lote2.xlsx',
#   'lote3.xlsx',
#   'lote5.xlsx',
#   'lote1.xlsx',
#   'lote17.xlsx',
#   'lote16.xlsx',
#   'lote8.xlsx',
#   'lote19.xlsx',
#   'lote15.xlsx',
#   'lote11.xlsx',
#   'lote4.xlsx',
#   'lote10.xlsx',
#   'lote14.xlsx',
#   'lote7.xlsx',
#   'lote22.xlsx',
#   'lote18.xlsx',
#   'lote9.xlsx',
#   'lote20.xlsx',
#   'lote6.xlsx',
#   'lote13.xlsx',
#   'lote21.xlsx'],
#  ['Lote19.xlsx',
#   'Lote20.xlsx',
#   'Lote9.xlsx',
#   'Lote4.xlsx',
#   'Lote15.xlsx',
#   'Lote6.xlsx',
#   'Lote5.xlsx',
#   'Lote8.xlsx',
#   'Lote21.xlsx',
#   'Lote10.xlsx',
#   'Lote17.xlsx',
#   'Lote3.xlsx',
#   'Lote1.xlsx',
#   'Lote12.xlsx',
#   'Lote13.xlsx',
#   'Lote18.xlsx',
#   'Lote14.xlsx',
#   'Lote7.xlsx',
#   'Lote2.xlsx',
#   'Lote11.xlsx'],
#  ['Lote1.xlsx']]

# %%
arr_lotes
# Out:
# [['infos.xlsx'],
#  ['infos.xlsx'],
#  ['infos.xlsx'],
#  ['infos.xlsx'],
#  ['infos.xlsx']]

# %%
for i in range(len(arr_licitacoes)):
    if arr_licitacoes[i] in list(df_licitacoes.Licitações):
        continue
    for k in range(len(arr_lotes[i])):
        df_licitacoes = df_licitacoes.append({'Licitações':arr_licitacoes[i],'Infos':arr_lotes[i][k]}, ignore_index=True)

# %%
for i in range(len(arr_licitacoes)):
    if arr_licitacoes[i] in list(df_lotes.Licitações):
        continue
    for k in range(len(arr_infos[i])):
        df_lotes = df_lotes.append({'Licitações':arr_licitacoes[i],'Lotes':arr_infos[i][k]}, ignore_index=True)

# %%
df_lotes
# Out:
#          Licitações        Lotes
# 0   708108 005.2018   Lote9.xlsx
# 1   708108 005.2018   Lote6.xlsx
# 2   708108 005.2018   Lote5.xlsx
# 3   708108 005.2018   Lote8.xlsx
# 4   708108 005.2018   Lote3.xlsx
# 5   708108 005.2018   Lote1.xlsx
# 6   708108 005.2018   Lote7.xlsx
# 7   708108 005.2018   Lote2.xlsx
# 8   683283 001.2018  lote12.xlsx
# 9   683283 001.2018   lote2.xlsx
# 10  683283 001.2018   lote3.xlsx
# 11  683283 001.2018   lote5.xlsx
# 12  683283 001.2018   lote1.xlsx
# 13  683283 001.2018  lote17.xlsx
# 14  683283 001.2018  lote16.xlsx
# 15  683283 001.2018   lote8.xlsx
# 16  683283 001.2018  lote15.xlsx
# 17  683283 001.2018  lote11.xlsx
# 18  683283 001.2018   lote4.xlsx
# 19  683283 001.2018  lote10.xlsx
# 20  683283 001.2018  lote14.xlsx
# 21  683283 001.2018   lote7.xlsx
# 22  683283 001.2018  lote18.xlsx
# 23  683283 001.2018   lote9.xlsx
# 24  683283 001.2018   lote6.xlsx
# 25  702880 003.2018  lote12.xlsx
# 26  702880 003.2018   lote2.xlsx
# 27  702880 003.2018   lote3.xlsx
# 28  702880 003.2018   lote5.xlsx
# 29  702880 003.2018   lote1.xlsx
# ..              ...          ...
# 38  702880 003.2018  lote14.xlsx
# 39  702880 003.2018   lote7.xlsx
# 40  702880 003.2018  lote22.xlsx
# 41  702880 003.2018  lote18.xlsx
# 42  702880 003.2018   lote9.xlsx
# 43  702880 003.2018  lote20.xlsx
# 44  702880 003.2018   lote6.xlsx
# 45  702880 003.2018  lote13.xlsx
# 46  702880 003.2018  lote21.xlsx
# 47  702852 002.2018  Lote19.xlsx
# 48  702852 002.2018  Lote20.xlsx
# 49  702852 002.2018   Lote9.xlsx
# 50  702852 002.2018   Lote4.xlsx
# 51  702852 002.2018  Lote15.xlsx
# 52  702852 002.2018   Lote6.xlsx
# 53  702852 002.2018   Lote5.xlsx
# 54  702852 002.2018   Lote8.xlsx
# 55  702852 002.2018  Lote21.xlsx
# 56  702852 002.2018  Lote10.xlsx
# 57  702852 002.2018  Lote17.xlsx
# 58  702852 002.2018   Lote3.xlsx
# 59  702852 002.2018   Lote1.xlsx
# 60  702852 002.2018  Lote12.xlsx
# 61  702852 002.2018  Lote13.xlsx
# 62  702852 002.2018  Lote18.xlsx
# 63  702852 002.2018  Lote14.xlsx
# 64  702852 002.2018   Lote7.xlsx
# 65  702852 002.2018   Lote2.xlsx
# 66  702852 002.2018  Lote11.xlsx
# 67  707266 004.2018   Lote1.xlsx
#
# [68 rows x 2 columns]

# %%
lote = read_excel('{}/{}/{}'.format(path, df_licitacoes.Licitações[1], df_licitacoes.Infos[1]))

# %%
info = read_excel('{}/{}/{}/{}'.format(path, df_lotes.Licitações[1], 'Lotes', df_lotes.Lotes[1]))

# %%
df_lotes
# Out:
#          Licitações        Lotes
# 0   708108 005.2018   Lote9.xlsx
# 1   708108 005.2018   Lote6.xlsx
# 2   708108 005.2018   Lote5.xlsx
# 3   708108 005.2018   Lote8.xlsx
# 4   708108 005.2018   Lote3.xlsx
# 5   708108 005.2018   Lote1.xlsx
# 6   708108 005.2018   Lote7.xlsx
# 7   708108 005.2018   Lote2.xlsx
# 8   683283 001.2018  lote12.xlsx
# 9   683283 001.2018   lote2.xlsx
# 10  683283 001.2018   lote3.xlsx
# 11  683283 001.2018   lote5.xlsx
# 12  683283 001.2018   lote1.xlsx
# 13  683283 001.2018  lote17.xlsx
# 14  683283 001.2018  lote16.xlsx
# 15  683283 001.2018   lote8.xlsx
# 16  683283 001.2018  lote15.xlsx
# 17  683283 001.2018  lote11.xlsx
# 18  683283 001.2018   lote4.xlsx
# 19  683283 001.2018  lote10.xlsx
# 20  683283 001.2018  lote14.xlsx
# 21  683283 001.2018   lote7.xlsx
# 22  683283 001.2018  lote18.xlsx
# 23  683283 001.2018   lote9.xlsx
# 24  683283 001.2018   lote6.xlsx
# 25  702880 003.2018  lote12.xlsx
# 26  702880 003.2018   lote2.xlsx
# 27  702880 003.2018   lote3.xlsx
# 28  702880 003.2018   lote5.xlsx
# 29  702880 003.2018   lote1.xlsx
# ..              ...          ...
# 38  702880 003.2018  lote14.xlsx
# 39  702880 003.2018   lote7.xlsx
# 40  702880 003.2018  lote22.xlsx
# 41  702880 003.2018  lote18.xlsx
# 42  702880 003.2018   lote9.xlsx
# 43  702880 003.2018  lote20.xlsx
# 44  702880 003.2018   lote6.xlsx
# 45  702880 003.2018  lote13.xlsx
# 46  702880 003.2018  lote21.xlsx
# 47  702852 002.2018  Lote19.xlsx
# 48  702852 002.2018  Lote20.xlsx
# 49  702852 002.2018   Lote9.xlsx
# 50  702852 002.2018   Lote4.xlsx
# 51  702852 002.2018  Lote15.xlsx
# 52  702852 002.2018   Lote6.xlsx
# 53  702852 002.2018   Lote5.xlsx
# 54  702852 002.2018   Lote8.xlsx
# 55  702852 002.2018  Lote21.xlsx
# 56  702852 002.2018  Lote10.xlsx
# 57  702852 002.2018  Lote17.xlsx
# 58  702852 002.2018   Lote3.xlsx
# 59  702852 002.2018   Lote1.xlsx
# 60  702852 002.2018  Lote12.xlsx
# 61  702852 002.2018  Lote13.xlsx
# 62  702852 002.2018  Lote18.xlsx
# 63  702852 002.2018  Lote14.xlsx
# 64  702852 002.2018   Lote7.xlsx
# 65  702852 002.2018   Lote2.xlsx
# 66  702852 002.2018  Lote11.xlsx
# 67  707266 004.2018   Lote1.xlsx
#
# [68 rows x 2 columns]

# %%
create_column(tabela_unica,'pdf_url')
create_column(tabela_unica,'classificacao')
create_column(tabela_unica,'fiscal')
create_column(tabela_unica,'valor_total')
create_column(tabela_unica,'numero_processo')
create_column(tabela_unica,'edital')
create_column(tabela_unica,'objeto')
create_column(tabela_unica,'contrato')
create_column(tabela_unica,'materiais_e_servicos')
create_column(tabela_unica,'demandante')
create_column(tabela_unica,'empresas')

create_column(df_materiais,'especificacoes')
create_column(df_materiais,'quantidade')
create_column(df_materiais,'valor_unitario')
create_column(df_materiais,'item')
create_column(df_materiais,'fornecedor')
create_column(df_materiais,'unidade')
create_column(df_materiais,'filename')

# %%
arr_infos
# Out:
# [['Lote9.xlsx',
#   'Lote6.xlsx',
#   'Lote5.xlsx',
#   'Lote8.xlsx',
#   'Lote3.xlsx',
#   'Lote1.xlsx',
#   'Lote7.xlsx',
#   'Lote2.xlsx'],
#  ['lote12.xlsx',
#   'lote2.xlsx',
#   'lote3.xlsx',
#   'lote5.xlsx',
#   'lote1.xlsx',
#   'lote17.xlsx',
#   'lote16.xlsx',
#   'lote8.xlsx',
#   'lote15.xlsx',
#   'lote11.xlsx',
#   'lote4.xlsx',
#   'lote10.xlsx',
#   'lote14.xlsx',
#   'lote7.xlsx',
#   'lote18.xlsx',
#   'lote9.xlsx',
#   'lote6.xlsx'],
#  ['lote12.xlsx',
#   'lote2.xlsx',
#   'lote3.xlsx',
#   'lote5.xlsx',
#   'lote1.xlsx',
#   'lote17.xlsx',
#   'lote16.xlsx',
#   'lote8.xlsx',
#   'lote19.xlsx',
#   'lote15.xlsx',
#   'lote11.xlsx',
#   'lote4.xlsx',
#   'lote10.xlsx',
#   'lote14.xlsx',
#   'lote7.xlsx',
#   'lote22.xlsx',
#   'lote18.xlsx',
#   'lote9.xlsx',
#   'lote20.xlsx',
#   'lote6.xlsx',
#   'lote13.xlsx',
#   'lote21.xlsx'],
#  ['Lote19.xlsx',
#   'Lote20.xlsx',
#   'Lote9.xlsx',
#   'Lote4.xlsx',
#   'Lote15.xlsx',
#   'Lote6.xlsx',
#   'Lote5.xlsx',
#   'Lote8.xlsx',
#   'Lote21.xlsx',
#   'Lote10.xlsx',
#   'Lote17.xlsx',
#   'Lote3.xlsx',
#   'Lote1.xlsx',
#   'Lote12.xlsx',
#   'Lote13.xlsx',
#   'Lote18.xlsx',
#   'Lote14.xlsx',
#   'Lote7.xlsx',
#   'Lote2.xlsx',
#   'Lote11.xlsx'],
#  ['Lote1.xlsx']]

# %%
for i in range(len(df_licitacoes)):
    if df_licitacoes.Licitações[i] in list(tabela_unica.numero_processo):
        continue
    lote = read_excel('{}/{}/{}'.format(path, df_licitacoes.Licitações[i], df_licitacoes.Infos[i]))
    for k in range(len(lote.index)):
        tabela_unica = tabela_unica.append({'pdf_url': None, 'classificacao': 'ATAS COM VIGÊNCIA EXPIRADA', 'fiscal': lote.pregoeiro[k], 'valor_total': 'R$ {}'.format(lote.ValorArrematado[k]), 'numero_processo':df_licitacoes.Licitações[i],'edital':lote.edital[k], 'objeto':lote.Descricao[k], 'contrato': None, 'materiais_e_servicos': 'SRP 632/2016', 'demandante': 'DISER', 'empresas': [{'valor_estimado': 'R$ {}'.format(lote.ValorUnitário[k]), 'nome_empresa': lote.Nome_Fantasia[k], 'termo_aditivo': None, 'vigencia': lote.vigencia[k], 'valor_global': 'R$ {}'.format(lote.ValorArrematado[k]), 'ata': None, 'descricao_empresa': lote.Atividade_Economica[k]}]}, ignore_index=True)
        info = read_excel('{}/{}/{}/{}'.format(path, df_licitacoes.Licitações[i], 'Lotes', arr_infos[i][k])) 
        for j in range(len(info.index)):
            df_materiais = df_materiais.append({'especificacoes': info.Descrição[j], 'quantidade': info.Quantidade[j], 'valor_unitario': lote.ValorUnitário[k], 'item': info.Item[j], 'fornecedor': lote.Nome_Fantasia[k], 'unidade': None, 'filename':None}, ignore_index=True)

# %% [markdown]
# df_materiais

# %%
df_materiais
# Out:
#                                         especificacoes quantidade  \
# 0    REFRIGERADOR, combinado frost free 2 portas , ...         50
# 1    REFRIGERADOR, domestico, duplex, capacidade to...         50
# 2    Freezer horizontal ,Conservação de produtos e ...        100
# 3    FOGAO a gás, industrial com 06 (seis) queimado...         40
# 4    FOGAO, a gás, modelo domestico, 04 queimadores...         40
# 5    FORNO, micro-ondas, capacidade total mínima 30...         50
# 6    FOGAO a Gás industrial, com 04 (quatro) queima...         20
# 7    PURIFICADOR DE ÁGUA, Ecocompressor: com gás R1...         60
# 8    BUFFET AQUECIMENTO 8 CUBAS Estrutura: Aço Inox...         10
# 9    Liquidificador industrial copo inox com 06 lt ...         50
# 10   Liquidificador industrial copo inox com 08 lt-...         30
# 11   Liquidificador industrial copo inox com 10 lt-...         20
# 12   BATEDEIRA, de bolo, de uso domestico, com duas...         20
# 13   BATEDEIRA, planetária, capacidade 5 litros par...         20
# 14   ESPREMEDOR de frutas, (corpo em aço inox ), in...         50
# 15   PROCESSADOR DE ALIMENTOS, COM 6 DISCOS DIÂMETR...         10
# 16   FRIGOBAR: Refrigerador Compacto. Cor: branco a...         30
# 17   BEBEDOURO, elétrico, tipo coluna, para garrafã...         50
# 18   BEBEDOURO, industrial, elétrico, com 3 torneir...         60
# 19   Bebedouro Industrial em Aço Inox 430 Brilhante...         20
# 20   Solução de Gelatina 3,5% 500 ml c/ sistema fec...        150
# 21   Soro Fisiológico c/ sistema fechado 0,9% 1.000...       2000
# 22   Soro Fisiológico c/ sistema fechado 0,9% 100 m...      40000
# 23   Soro Fisiológico c/ sistema fechado 0,9% 250 m...      50000
# 24   Soro Fisiológico c/ sistema fechado 0,9% 500 m...      60000
# 25   Soro Glico-Fisiológico c/ sistema fechado 500 ...      30000
# 26   Soro Glicosado 5% c/ sistema fechado 250 ml, b...       4000
# 27   Soro Glicosado 5% c/ sistema fechado 500 ml bo...      30000
# 28   Soro Manitol 20% c/ sistema fechado 250 ml, bo...        200
# 29   Soro Ringer Lactato c/ sistema fechado 500 ml,...      50000
# ..                                                 ...        ...
# 372                                PASTA D'ÁGUA, Pasta        500
# 373  Paracetamol 200mg/ml  solução oral Frasco c/ ...      25000
# 374                    Permetrina loção 1%. Fr c/ 60ml       1000
# 375  Prednisolona, fosfato sódico de, solução oral ...       1000
# 376         Salbutamol xarope 2mg/5ml. Frasco c/ 100ml        500
# 377  Sais p/ Hidratação Oral, pó para solução oral,...      12000
# 378  Sulfato Ferroso 25mg/ml Fe++ - solução oral/go...       1000
# 379  Sulfato Ferroso 25mg/ml Fe++ - Xarope. Frasco ...       4000
# 380                  Timolol, maleato de, 0,5% colírio       1000
# 381  Beclometasona 50mcg/dose - spray inalatório - ...        200
# 382  Beclometasona pó, solução inalante ou aerossol...        600
# 383         Budesonida 32mcg, 120 doses - frasco c/6ml        500
# 384                      Cetoconazol 20mg/g (2%) Xampu        100
# 385                                     Doxazosina 2mg       1000
# 386                                    Finasterida 5mg       1000
# 387  Salbutamol, sulfato de, aerossol oral 100mcg/d...       3000
# 388  Cadeira Acadêmica em ABS Cadeira Escolar com p...       6000
# 389  Conjunto Coletivo Infantil. Formada por 6 mesa...        300
# 390  Armário Professor em Fórmica Composto de duas ...         50
# 391  Estante em Fórmica Composto por 3 prateleiras....        100
# 392  Estante em Aço com 3 prateleiras 18 Lts (Guard...         30
# 393  Conjunto mesa e cadeira para professor Tampo d...        400
# 394  Mesa acessível Mesa regulável, com tampo em co...         50
# 395  Conjunto refeitório em resina termoplástica co...         50
# 396  Conjunto Hexagonal em resina termoplástica Com...         50
# 397  Longarinas de 3 lugares. Cadeira com assento e...         60
# 398  Longarina de 3 lugares com prancheta Cadeira c...         40
# 399  Mesa de reunião redonda, borda de 15 mm, 1,20 ...          2
# 400  Mesa de Reunião semi oval, borda de 40 mm, med...          1
# 401  Cadeira giratória estofada com espaldar médio,...         26
#
#      valor_unitario item                                       fornecedor  \
# 0           965.000    1  AQUALIMP PRODUTOS HOSPITALES, HIGIENE E LIMPEZA
# 1           965.000    2  AQUALIMP PRODUTOS HOSPITALES, HIGIENE E LIMPEZA
# 2          1276.840    1                                WFL DISTRIBUIDORA
# 3          1999.932    1                                 MASTER COMERCIAL
# 4          1999.932    2                                 MASTER COMERCIAL
# 5          1999.932    3                                 MASTER COMERCIAL
# 6          1999.932    4                                 MASTER COMERCIAL
# 7           133.320    1                                WFL DISTRIBUIDORA
# 8          2130.000    1                                WFL DISTRIBUIDORA
# 9           820.000    1                                WFL DISTRIBUIDORA
# 10          820.000    2                                WFL DISTRIBUIDORA
# 11          820.000    3                                WFL DISTRIBUIDORA
# 12          820.000    4                                WFL DISTRIBUIDORA
# 13          820.000    5                                WFL DISTRIBUIDORA
# 14          820.000    6                                WFL DISTRIBUIDORA
# 15          820.000    7                                WFL DISTRIBUIDORA
# 16          578.170    1  AQUALIMP PRODUTOS HOSPITALES, HIGIENE E LIMPEZA
# 17         2099.000    1                                WFL DISTRIBUIDORA
# 18         2099.000    2                                WFL DISTRIBUIDORA
# 19         2099.000    3                                WFL DISTRIBUIDORA
# 20           62.750    1                                          MEDISIL
# 21           62.750    2                                          MEDISIL
# 22           62.750    3                                          MEDISIL
# 23           62.750    4                                          MEDISIL
# 24           62.750    5                                          MEDISIL
# 25           62.750    6                                          MEDISIL
# 26           62.750    7                                          MEDISIL
# 27           62.750    8                                          MEDISIL
# 28           62.750    9                                          MEDISIL
# 29           62.750   10                                          MEDISIL
# ..              ...  ...                                              ...
# 372          93.050   17                                          DISOMED
# 373          93.050   18                                          DISOMED
# 374          93.050   19                                          DISOMED
# 375          93.050   20                                          DISOMED
# 376          93.050   21                                          DISOMED
# 377          93.050   22                                          DISOMED
# 378          93.050   23                                          DISOMED
# 379          93.050   24                                          DISOMED
# 380          93.050   25                                          DISOMED
# 381          93.050   26                                          DISOMED
# 382          93.050   27                                          DISOMED
# 383          93.050   28                                          DISOMED
# 384          93.050   29                                          DISOMED
# 385          93.050   30                                          DISOMED
# 386          93.050   31                                          DISOMED
# 387          93.050   32                                          DISOMED
# 388         297.650    1                        GAUS INDUSTRIA E COMERCIO
# 389         297.650    2                        GAUS INDUSTRIA E COMERCIO
# 390         297.650    3                        GAUS INDUSTRIA E COMERCIO
# 391         297.650    4                        GAUS INDUSTRIA E COMERCIO
# 392         297.650    5                        GAUS INDUSTRIA E COMERCIO
# 393         297.650    6                        GAUS INDUSTRIA E COMERCIO
# 394         297.650    7                        GAUS INDUSTRIA E COMERCIO
# 395         297.650    8                        GAUS INDUSTRIA E COMERCIO
# 396         297.650    9                        GAUS INDUSTRIA E COMERCIO
# 397         297.650   10                        GAUS INDUSTRIA E COMERCIO
# 398         297.650   11                        GAUS INDUSTRIA E COMERCIO
# 399         297.650   12                        GAUS INDUSTRIA E COMERCIO
# 400         297.650   13                        GAUS INDUSTRIA E COMERCIO
# 401         297.650   14                        GAUS INDUSTRIA E COMERCIO
#
#     unidade filename
# 0      None     None
# 1      None     None
# 2      None     None
# 3      None     None
# 4      None     None
# 5      None     None
# 6      None     None
# 7      None     None
# 8      None     None
# 9      None     None
# 10     None     None
# 11     None     None
# 12     None     None
# 13     None     None
# 14     None     None
# 15     None     None
# 16     None     None
# 17     None     None
# 18     None     None
# 19     None     None
# 20     None     None
# 21     None     None
# 22     None     None
# 23     None     None
# 24     None     None
# 25     None     None
# 26     None     None
# 27     None     None
# 28     None     None
# 29     None     None
# ..      ...      ...
# 372    None     None
# 373    None     None
# 374    None     None
# 375    None     None
# 376    None     None
# 377    None     None
# 378    None     None
# 379    None     None
# 380    None     None
# 381    None     None
# 382    None     None
# 383    None     None
# 384    None     None
# 385    None     None
# 386    None     None
# 387    None     None
# 388    None     None
# 389    None     None
# 390    None     None
# 391    None     None
# 392    None     None
# 393    None     None
# 394    None     None
# 395    None     None
# 396    None     None
# 397    None     None
# 398    None     None
# 399    None     None
# 400    None     None
# 401    None     None
#
# [402 rows x 7 columns]
